# %%
import pandas as pd

data = pd.read_csv("../out/out.csv")

# %%
data
# Out:
#           Open Time  long_decision_forward_1  short_decision_forward_1  \
# 0     1515801600000                       -1                         1
# 1     1515888000000                        0                        -1
# 2     1515974400000                       -1                         1
# 3     1516060800000                       -1                        -1
# 4     1516147200000                       -1                        -1
# ...             ...                      ...                       ...
# 1809  1672099200000                        0                         0
# 1810  1672185600000                        0                         0
# 1811  1672272000000                        0                         0
# 1812  1672358400000                        0                         0
# 1813  1672444800000                        2                         2
#
#       long_decision_forward_2  short_decision_forward_2  \
# 0                           2                         2
# ...

# %%
a= data["long_decision_forward_1"] == data["long_decision_forward_2"]

# %%
a
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#         ...
# 1809    True
# 1810    True
# 1811    True
# 1812    True
# 1813    True
# Length: 1814, dtype: bool
