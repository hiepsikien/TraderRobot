# %%
import pandas as pd
from config import AGGREGATED_DATA_PATH
import matplotlib.pyplot as plt

# %%
btc_data = pd.read_hdf(f"{AGGREGATED_DATA_PATH}BTCUSDT-1s.h5")

# %%
btc_1h_data = pd.read_csv("../data/BTCUSDT-1h.csv")

# %%
btc_data

# %%
btc_1h_data

# %%
btc_data["return"] = btc_data["Close"]/btc_data["Close"].shift() - 1

# %%
sell_threshold = -0.005
buy_threshold = 0.005
big_sell = btc_data[btc_data["return"] < sell_threshold]
big_buy = btc_data[btc_data["return"] > buy_threshold]

# %%
len(big_sell)
# Out:
# 55

# %%
len(big_buy)
# Out:
# 40

# %%
plt.figure(figsize=(16,8),dpi=720)
plt.plot(btc_1h_data[-10000:]["Open Time"],btc_1h_data[-10000:]["Close"],c="b",linewidth=1)
plt.scatter(big_sell.index,big_sell["Close"],c="r")
# plt.scatter(big_buy.index,big_buy["Close"],c="g")
plt.show()
