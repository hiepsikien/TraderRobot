# %%
import downloader as dl
import importlib
import pandas as pd

# %%
importlib.reload(dl)

# %%
dl.download_spot_and_save_to_hdf(
    symbol="ETHUSDT",
    interval="1d",
    start_year=2017,
    start_month=8,
    end_year=2023,
    end_month=2
)

# %%
dl.download_futures_and_save_to_hdf(
    symbol="BTCUSDT",
    interval="1d",
    start_year=2020,
    start_month=1,
    end_year=2023,
    end_month=2
)

# %%
# %store -r tickers

# %%
tickers

# %%
len(tickers)

# %%
usdt_lists = []
for ticker in tickers:
    symbol = ticker["symbol"]
    if str(symbol).endswith("USDT"):
        usdt_lists.append(symbol)

# %%
len(usdt_lists)

# %%
for symbol in usdt_lists:
    dl.download_futures_and_save_to_hdf(
    symbol=symbol,
    interval="12h",
    start_year=2020,
    start_month=1,
    end_year=2023,
    end_month=2
)
# Out:
# ...downloading ...
# /media/andy/UbuntuDisk/CryptoData/futures/monthly/klines/CFXUSDT/12h/CFXUSDT-12h-2023-02.zip
# Total downloaded 1 files
# ...unzipping...
# /media/andy/UbuntuDisk/CryptoData/futures/monthly/klines/CFXUSDT/12h/CFXUSDT-12h-2023-02.zip
# ...merging...
# /media/andy/UbuntuDisk/CryptoData/futures/monthly/klines/CFXUSDT/12h/CFXUSDT-12h-2023-02.csv
# ...saving...
# Completed
# ...downloading ...
# /media/andy/UbuntuDisk/CryptoData/futures/monthly/klines/SSVUSDT/12h/SSVUSDT-12h-2023-02.zip
# Total downloaded 1 files
# ...unzipping...
# /media/andy/UbuntuDisk/CryptoData/futures/monthly/klines/SSVUSDT/12h/SSVUSDT-12h-2023-02.zip
# ...merging...
# /media/andy/UbuntuDisk/CryptoData/futures/monthly/klines/SSVUSDT/12h/SSVUSDT-12h-2023-02.csv
# ...saving...
# Completed
# ...downloading ...
# /media/andy/UbuntuDisk/CryptoData/futures/monthly/klines/SOLUSDT/12h/SOLUSDT-12h-2020-09.zip
# /media/andy/UbuntuDisk/CryptoData/futures/monthly/klines/SOLUSDT/12h/SOLUSDT-12h-2020-10.zip
# ...
