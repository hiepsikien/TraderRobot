# %%
import feature_manager as fma
import matplotlib.pyplot as plt
from ta import ta_backtester as tb

# %% [markdown]
# ### Import Data

# %%
fm = fma.FeatureManager("trade_signal")
fm.import_data("BTCUSDT",["15m","1h","4h","1d","1w","1mo"])
m15,h1,h4,d,w, mo = fm.dfs[0],fm.dfs[1],fm.dfs[2],fm.dfs[3],fm.dfs[4],fm.dfs[5]

# %% [markdown]
# ### Backtest MACD

# %%
df = tb.backtest_macd_combination(df=w,n_last=8)
# Out:
# Calculating MACD. . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . .

# %%
w.tail(36)["Close"].plot()
# Out:
# <AxesSubplot: xlabel='Open Time'>

# %%
df.nlargest(10,"sharpe_n")
# Out:
#       slow  fast  tp  fp  tn  fn  duration  mean_p  std_p    mean_n     std_n  \
# 1176    13    12   0   0   5   3        11     NaN    NaN  0.083266  0.189015
# 1187    14    12   0   0   5   3        11     NaN    NaN  0.083266  0.189015
# 1198    15    12   0   0   5   3        11     NaN    NaN  0.083266  0.189015
# 1209    16    12   0   0   5   3        11     NaN    NaN  0.083266  0.189015
# 1220    17    12   0   0   5   3        11     NaN    NaN  0.083266  0.189015
# 1231    18    12   0   0   5   3        11     NaN    NaN  0.083266  0.189015
# 1242    19    12   0   0   5   3        11     NaN    NaN  0.083266  0.189015
# 1253    20    12   0   0   5   3        11     NaN    NaN  0.083266  0.189015
# 1264    21    12   0   0   5   3        11     NaN    NaN  0.083266  0.189015
# 1275    22    12   0   0   5   3        11     NaN    NaN  0.083266  0.189015
#
#       recall_p  recall_n  n    acc  precise_p  precise_n  sharpe_p  sharpe_n
# 1176       0.0     0.625  8  0.625        NaN      0.625       NaN  0.440524
# 1187       0.0     0.625  8  0.625        NaN      0.625       NaN  0.440524
# 1198       0.0     0.625  8  0.625        NaN      0.625       NaN  0.440524
# 1209       0.0     0.625  8  0.625        NaN      0.625       NaN  0.440524
# 1220       0.0     0.625  8  0.625        NaN      0.625       NaN  0.440524
# 1231       0.0     0.625  8  0.625        NaN      0.625       NaN  0.440524
# 1242       0.0     0.625  8  0.625        NaN      0.625       NaN  0.440524
# 1253       0.0     0.625  8  0.625        NaN      0.625       NaN  0.440524
# 1264       0.0     0.625  8  0.625        NaN      0.625       NaN  0.440524
# 1275       0.0     0.625  8  0.625        NaN      0.625       NaN  0.440524

# %% [markdown]
# ### Backtest RSI

# %%
df = tb.backtest_rsi_combination(df=m15,n_last=5000,period_min=3,period_max=30)

# %%
df.nlargest(10,"acc")
