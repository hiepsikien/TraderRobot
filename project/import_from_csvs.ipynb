# %%
import pandas as pd
import numpy as np
import glob

# %%
data_path = "/home/andy/CryptoTradingPlatform/Historical"

def import_data_from_multiple_csv(path,symbol,interval):
   
    col_names = ["Open","High","Low","Close","Volumn","Close Time", "Quote Asset Volumn", "Number of Trades", "Taker Buy Base Asset Volumn", "Taker Buy Quote Asset Volumn", "Ignore" ]
    filenames = glob.glob("{}/{}/{}/*.csv".format(path,interval,symbol))
    dfs = []

    for filename in filenames:
        dfs.append(pd.read_csv(filename, names = col_names))

    data = pd.concat(dfs)
    data.index.name = "Date"

    data = data.sort_index(ascending=True)

    data["Date Time"] = pd.to_datetime(data.index,unit="ms",utc=True)

    data.index.name = "Open Time"

    return data

def write_data_to_csv(data,symbol,timeframe):
    data.to_csv("../data/{}-{}.csv".format(symbol,timeframe))

# %%
data_btc = import_data_from_multiple_csv(data_path,"BTCUSDT","1w")

# %%
data_btc
# Out:
#                    Open      High       Low     Close        Volumn  \
# Open Time
# 1502668800000   4261.48   4485.39   3850.00   4086.29  2.843431e+03
# 1503273600000   4069.13   4453.91   3400.00   4310.01  4.599397e+03
# 1503878400000   4310.01   4939.19   4124.54   4509.08  4.753843e+03
# 1504483200000   4505.00   4788.59   3603.00   4130.37  6.382788e+03
# 1505088000000   4153.62   4394.59   2817.00   3699.99  8.106705e+03
# ...                 ...       ...       ...       ...           ...
# 1672012800000  16832.11  16972.83  16333.00  16616.75  1.028682e+06
# 1672617600000  16617.17  17176.99  16548.70  17127.83  1.112350e+06
# 1673222400000  17127.83  21258.00  17104.66  20871.50  2.145456e+06
# 1673827200000  20872.99  23371.80  20407.15  22707.88  2.108890e+06
# 1674432000000  22706.02  23960.54  22300.00  23742.30  1.946353e+06
#
#                   Close Time  Quote Asset Volumn  Number of Trades  \
# Open Time
# 1502668800000  1503273599999        1.202158e+07             13134
# 1503273600000  1503878399999        1.897898e+07             37826
# 1503878400000  1504483199999        2.158168e+07             35717
# 1504483200000  1505087999999        2.730782e+07             42372
# 1505088000000  1505692799999        3.002680e+07             50423
# ...                      ...                 ...               ...
# 1672012800000  1672617599999        1.712865e+10          29855688
# 1672617600000  1673222399999        1.871080e+10          32938345
# 1673222400000  1673827199999        4.031016e+10          48190928
# 1673827200000  1674431999999        4.562264e+10          48516459
# 1674432000000  1675036799999        4.477842e+10          48187520
#
#                Taker Buy Base Asset Volumn  Taker Buy Quote Asset Volumn  \
# Open Time
# 1502668800000                 2.240249e+03                  9.482743e+06
# 1503273600000                 1.755530e+03                  7.173180e+06
# 1503878400000                 1.371034e+03                  6.237542e+06
# 1504483200000                 2.821423e+03                  1.212098e+07
# 1505088000000                 3.763128e+03                  1.395615e+07
# ...                                    ...                           ...
# 1672012800000                 5.126739e+05                  8.536394e+09
# 1672617600000                 5.533734e+05                  9.308405e+09
# 1673222400000                 1.067943e+06                  2.007216e+10
# 1673827200000                 1.049279e+06                  2.270286e+10
# 1674432000000                 9.689962e+05                  2.229593e+10
#
#                      Ignore                 Date Time
# Open Time
# 1502668800000  10125.414084 2017-08-14 00:00:00+00:00
# 1503273600000  11456.953073 2017-08-21 00:00:00+00:00
# 1503878400000  12653.029273 2017-08-28 00:00:00+00:00
# 1504483200000  10431.327491 2017-09-04 00:00:00+00:00
# 1505088000000   8391.646478 2017-09-11 00:00:00+00:00
# ...                     ...                       ...
# 1672012800000      0.000000 2022-12-26 00:00:00+00:00
# 1672617600000      0.000000 2023-01-02 00:00:00+00:00
# 1673222400000      0.000000 2023-01-09 00:00:00+00:00
# 1673827200000      0.000000 2023-01-16 00:00:00+00:00
# 1674432000000      0.000000 2023-01-23 00:00:00+00:00
#
# [247 rows x 12 columns]

# %%
data_btc

# %%
write_data_to_csv(data_btc,symbol="BTCUSDT",timeframe="1w")

# %%
data_btc["Swing"]=(data_btc["High"]-data_btc["Low"])/data_btc["Close"]

# %%
data_btc["Swing"].describe()
# Out:
# count    247.000000
# mean       0.169092
# std        0.106197
# min        0.028660
# 25%        0.098357
# 50%        0.143484
# 75%        0.208132
# max        0.820170
# Name: Swing, dtype: float64
