# %%
import pandas as pd
import numpy as np
import glob

# %%
data_path = "/home/andy/CryptoTradingPlatform/Historical"

def import_data_from_multiple_csv(path,symbol,interval):
   
    col_names = ["Open","High","Low","Close","Volumn","Close Time", "Quote Asset Volumn", "Number of Trades", "Taker Buy Base Asset Volumn", "Taker Buy Quote Asset Volumn", "Ignore" ]
    filenames = glob.glob("{}/{}/{}/*.csv".format(path,interval,symbol))
    dfs = []

    for filename in filenames:
        dfs.append(pd.read_csv(filename, names = col_names))

    data = pd.concat(dfs)
    data.index.name = "Date"

    data = data.sort_index(ascending=True)

    data["Date Time"] = pd.to_datetime(data.index,unit="ms",utc=True)

    data.index.name = "Open Time"

    return data

def write_data_to_csv(data,symbol,timeframe):
    data.to_csv("../data/{}-{}.csv".format(symbol,timeframe))

# %%
data_btc = import_data_from_multiple_csv(data_path,"BTCUSDT","1mo")

# %%
data_btc
# Out:
#                    Open      High       Low     Close        Volumn  \
# Open Time
# 1501545600000   4261.48   4745.42   3400.00   4724.89  1.001564e+04
# 1504224000000   4689.89   4939.19   2817.00   4378.51  2.763419e+04
# 1506816000000   4378.49   6498.01   4110.00   6463.00  4.162639e+04
# 1509494400000   6463.00  11300.03   5325.01   9838.96  1.084880e+05
# 1512086400000   9837.00  19798.68   9380.00  13716.36  4.084767e+05
# ...                 ...       ...       ...       ...           ...
# 1661990400000  20048.44  22799.00  18125.98  19422.61  9.838931e+06
# 1664582400000  19422.61  21085.00  18190.00  20490.74  7.499122e+06
# 1667260800000  20490.74  21480.65  15476.00  17163.64  9.127694e+06
# 1669852800000  17165.53  18387.95  16256.30  16542.40  5.803834e+06
# 1672531200000  16541.77  23960.54  16499.01  23125.13  7.977029e+06
#
#                   Close Time  Quote Asset Volumn  Number of Trades  \
# Open Time
# 1501545600000  1504223999999        4.253830e+07             69180
# 1504224000000  1506815999999        1.104931e+08            228745
# 1506816000000  1509494399999        2.287368e+08            303389
# 1509494400000  1512086399999        8.927488e+08            577424
# 1512086400000  1514764799999        5.975574e+09           3082883
# ...                      ...                 ...               ...
# 1661990400000  1664582399999        1.949544e+11         175214455
# 1664582400000  1667260799999        1.477583e+11         155718643
# 1667260800000  1669852799999        1.637218e+11         204731238
# 1669852800000  1672531199999        9.863616e+10         137340627
# 1672531200000  1675209599999        1.641314e+11         195640242
#
#                Taker Buy Base Asset Volumn  Taker Buy Quote Asset Volumn  \
# Open Time
# 1501545600000                 4.610019e+03                  1.941923e+07
# 1504224000000                 1.235317e+04                  4.919992e+07
# 1506816000000                 1.923186e+04                  1.053401e+08
# 1509494400000                 5.547698e+04                  4.644876e+08
# 1512086400000                 2.139406e+05                  3.122654e+09
# ...                                    ...                           ...
# 1661990400000                 4.913377e+06                  9.738160e+10
# 1664582400000                 3.743307e+06                  7.376535e+10
# 1667260800000                 4.534847e+06                  8.135464e+10
# 1669852800000                 2.881079e+06                  4.896656e+10
# 1672531200000                 3.970265e+06                  8.170306e+10
#
#                      Ignore                 Date Time
# Open Time
# 1501545600000  10779.838731 2017-08-01 00:00:00+00:00
# 1504224000000  11158.769785 2017-09-01 00:00:00+00:00
# 1506816000000  15785.318159 2017-10-01 00:00:00+00:00
# 1509494400000  34507.182977 2017-11-01 00:00:00+00:00
# 1512086400000      0.000000 2017-12-01 00:00:00+00:00
# ...                     ...                       ...
# 1661990400000      0.000000 2022-09-01 00:00:00+00:00
# 1664582400000      0.000000 2022-10-01 00:00:00+00:00
# 1667260800000      0.000000 2022-11-01 00:00:00+00:00
# 1669852800000      0.000000 2022-12-01 00:00:00+00:00
# 1672531200000      0.000000 2023-01-01 00:00:00+00:00
#
# [65 rows x 12 columns]

# %%
write_data_to_csv(data_btc,symbol="BTCUSDT",timeframe="1mo")

# %%
data_btc["Swing"]=(data_btc["High"]-data_btc["Low"])/data_btc["Close"]

# %%
data_btc["Swing"].describe()
# Out:
# count    65.000000
# mean      0.357194
# std       0.165595
# min       0.114356
# 25%       0.252733
# 50%       0.314024
# 75%       0.399071
# max       0.791865
# Name: Swing, dtype: float64
