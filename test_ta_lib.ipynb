# %%
import talib as ta
import pandas as pd
from my_logging import logger
filepath = "bitcoin.csv"

# %%
raw = pd.read_csv(filepath, parse_dates=["Date"],index_col="Date") 
close = raw[["Close"]].to_numpy().flatten()

# %%
close
# Out:
# array([ 4308.83,  4315.32,  4324.35, ..., 54755.92, 54538.3 , 53995.5 ])

# %%
macd, macd_signal, macd_hist = ta.MACD(close,fastperiod=12,slowperiod=26,signalperiod=9)

# %%
logger.info(macd_hist)

# %%
for p in macd_hist:
    print(p)
# Out:
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# 12.77458715911871
# 8.059032395503163
# 3.5111596076772535
# 1.5936741881811471
# -3.0735661788918875
# -10.421974673512654
# -12.99136519668329
# -20.955177852324937
# -27.38359043388582
# -20.74097828568854
# -15.3606505829354
# -7.157565294035642
# -2.071277863050007
# 2.25586941072433
# 4.235110587769007
# 1.282085475899855
# 0.43300170339470867
# -5.36350134343644
# -5.21907499771919
# -6.520362949443914
# -2.0287425158872026
# -2.8686063478646346
# -5.4271088089900985
# 2.5950999376319146
# 4.533911945838966
# 6.231993033934813
# 3.021746233505006
# 3.1703684036322244
# 5.372233396749117
# 10.7468086988885
# 13.39457669466477
# 14.803996542640625
# 15.226871903571059
# 19.28221965392008
# 21.1617832200602
# 18.09171169583259
# 15.25095135909286
# 15.58581976980625
# ...
